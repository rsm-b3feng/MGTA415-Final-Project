# %%
import pandas as pd

# %%
df.columns
# Out:
# Index(['age', 'status', 'sex', 'orientation', 'body_type', 'diet', 'drinks',
#        'drugs', 'education', 'ethnicity', 'height', 'income', 'job',
#        'last_online', 'location', 'offspring', 'pets', 'religion', 'sign',
#        'smokes', 'speaks', 'essay0', 'essay1', 'essay2', 'essay3', 'essay4',
#        'essay5', 'essay6', 'essay7', 'essay8', 'essay9'],
#       dtype='object')

# %%
df = pd.read_csv('okcupid_profiles.csv')
df.head()
# Out:
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
# 3   23     single   m    straight            thin         vegetarian
# 4   29     single   m    straight        athletic                NaN
#
#      drinks      drugs                          education  \
# 0  socially      never      working on college/university
# 1     often  sometimes              working on space camp
# 2  socially        NaN     graduated from masters program
# 3  socially        NaN      working on college/university
# 4  socially      never  graduated from college/university
#
#              ethnicity  ...  \
# 0         asian, white  ...
# 1                white  ...
# 2                  NaN  ...
# 3                white  ...
# 4  asian, black, other  ...
#
# ...

# %%
df["age"].hist(bins=20)  # Age distribution
# Out:
# <Axes: >

# %%
df["sex"].value_counts().plot(kind="bar")  # Gender distribution
# Out:
# <Axes: xlabel='sex'>

# %%
df["orientation"].value_counts().plot(kind="bar")  # Sexual orientation breakdown
# Out:
# <Axes: xlabel='orientation'>

# %%
df["drinks"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='drinks'>

# %%
df["drugs"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='drugs'>

# %%
df["education"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='education'>

# %%
df[["essay0", "essay1", "essay2", "essay3"]].isnull().sum()
# Out:
# essay0     5488
# essay1     7572
# essay2     9638
# essay3    11476
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Calculate the number of missing values per column
missing_values = df.isnull().sum()

# Plot the missing values
plt.figure(figsize=(12, 6))
missing_values.plot(kind="bar", color="orange")
plt.xlabel("Variables")
plt.ylabel("Number of Missing Values")
plt.title("Frequency of Missing Values per Variable")
plt.xticks(rotation=90)
plt.show()

# %%
pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay0"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#              age    height    income
# age     1.000000 -0.022262 -0.001004
# height -0.022262  1.000000  0.065049
# income -0.001004  0.065049  1.000000

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay1"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay2"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay3"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay4"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay5"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay6"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay6"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay7"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay7"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay8"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["essay9"].dropna())
wordcloud = WordCloud(width=800, height=400).generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract city names from the location column
df["city"] = df["location"].apply(lambda x: x.split(",")[0] if pd.notnull(x) else "Unknown")

# Count the percentage of users by city
city_counts = df["city"].value_counts(normalize=True) * 100

# Select the top 10 cities
top_cities = city_counts.head(10)

# Plot the bar chart
plt.figure(figsize=(12, 6))
top_cities.plot(kind="bar", color="blue")
plt.xlabel("City")
plt.ylabel("Percentage of Users")
plt.title("Top 10 Cities by Percentage of Users")
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the number of missing values per column
missing_values = df.isnull().sum()

# Plot the missing values
plt.figure(figsize=(12, 6))
missing_values.plot(kind="bar", color="orange")
plt.xlabel("Variables")
plt.ylabel("Number of Missing Values")
plt.title("Frequency of Missing Values per Variable")
plt.xticks(rotation=90)
plt.show()
